# %% [markdown]
# # LGM VIP AUGUST 2021 BATCH
#
#
#
#
#
# ## Name-Rahul Pahuja
# ### Task-5: Exploratory Data Analysis on Terroris Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/sample_data/globalterrorismdb_0718dist.csv",encoding='iso-8859-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       197000000001   1970       7     2  ...        0         0       0      NaN
# 1       197000000002   1970       0     0  ...        1         1       1      NaN
# 2       197001000001   1970       1     0  ...       -9         1       1      NaN
# 3       197001000002   1970       1     0  ...       -9         1       1      NaN
# 4       197001000003   1970       1     0  ...       -9         1       1      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# ...

# %%
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df['iyear'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: iyear, dtype: int64

# %%
df['iyear'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017])

# %%
df['region'].value_counts()
# Out:
# 10    50474
# 6     44974
# 3     18978
# 11    17550
# 8     16639
# 5     12485
# 2     10344
# 9      5144
# 1      3456
# 4       802
# 7       563
# 12      282
# Name: region, dtype: int64

# %%
df['city'].value_counts()
# Out:
# Unknown        9775
# Baghdad        7589
# Karachi        2652
# Lima           2359
# Mosul          2265
#                ...
# Kerene            1
# Karlapodar        1
# Mykolayivka       1
# Tilauthar         1
# Wajriko           1
# Name: city, Length: 36674, dtype: int64

# %%
df['country_txt'].value_counts()
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Vatican City               1
# New Hebrides               1
# Antigua and Barbuda        1
# North Korea                1
# Wallis and Futuna          1
# Name: country_txt, Length: 205, dtype: int64

# %%
df.corr()
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002706  ... -0.133252 -0.077852 -0.175605
# iyear      0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth     0.002706  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday       0.018336  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091761  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077852 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175605 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %%
# correlation matrix 

sns.set(style="white")
# Create a covariance matrix
corr = df.corr()
# Creating a mask the size of our covariance matrix
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220,10,as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask,cmap=cmap,vmax=1,center=0,square=True, 
            linewidth=.5, cbar_kws={'shrink': .5})
ax.set_title('Multi-Collinearity of Features')
plt.savefig('correlation2.png')

#As the color becomes darker in either direction (red or blue) that means that those variables are more highly correlated 
#and should not be paired together in the same model.

# %%
plt.figure(figsize=(15,9))
x = df['country_txt'].value_counts().index[:30]
y = df['country_txt'].value_counts().values[:30]
sns.barplot(x,y,palette='deep')
plt.title(' Top 30 Countries Affected By Terrorism',size=20)
plt.xlabel('Countries',size=15)
plt.ylabel('Count',size=15)
plt.xticks(size=13,rotation= 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,10))
df['attacktype1_txt'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()

# %%
df[['attacktype1_txt','nwound']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['red'])
plt.xticks(rotation=20)
plt.title("wounded people record  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('type of attack',fontsize=15)
plt.show()

# %%
top_city = df.city.value_counts().reset_index().rename(columns={'index': 'City Name'})
top_city.columns.values[1] = 'Count of Attacks'
top_city = top_city.head(10)
plt.title('Most Attacked Cities',fontsize=25)
explode = (0.2,0,0,0,0,0,0,0,0,0)
mycolors=["orange","hotpink","b","green","yellow","red","purple","brown","grey","black"]
plt.pie(top_city['Count of Attacks'], labels=top_city['City Name'],shadow=True,explode=explode,colors=mycolors,autopct='%1.1f%%')
plt.show()

# %%
target_type= df['targtype1_txt'].value_counts().reset_index().rename(columns={'index': 'Target Types'})
target_type.columns.values[1] = 'Count'

fig,ax = plt.subplots(figsize=(30, 15))
sns.despine()

sns.barplot(x="Target Types",y="Count",data=target_type.head(15),palette="Blues_d")

ax.set_title('Most Targeted Places',fontsize=35)
ax.set_ylabel(ylabel = 'Count of Attacks',fontsize = 15)
ax.set_xlabel(xlabel = 'Target places',fontsize = 15)

ax.legend();
# Out:
# No handles with labels found to put in legend.

# %%
weapons= df['weaptype1_txt'].value_counts().reset_index()
weapons.columns.values[1] = 'Count of Attacks'
sns.set(style='whitegrid')
fig,ax = plt.subplots(figsize=(30,15))
sns.despine()
sns.barplot(x="index", y="Count of Attacks", data=weapons.head(7),palette="pink")
ax.set_title('Most Used Weapons',fontsize=30)
ax.set_ylabel(ylabel = 'Count of Attacks', fontsize =20)
ax.set_xlabel(xlabel = 'Weapon used', fontsize =20)
ax.legend();
# Out:
# No handles with labels found to put in legend.

# %%
most_att = df.city.value_counts().reset_index().rename(columns={'index': 'Country Name'})
most_att.columns.values[1] = 'Count of Attacks'
most_att = most_att.head(10)
plt.title('Most Attacked Countries',fontsize=25)
explode = (0.2,0,0,0,0,0,0,0,0,0)
mycolors=["orange","hotpink","b","green","yellow","red","purple","brown","grey","black"]
plt.pie(most_att['Count of Attacks'], labels=most_att['Country Name'],shadow=True,explode=explode,colors=mycolors,autopct='%1.1f%%')
plt.show()
print("Iraq has the highest attacks with percentage of 24.7%")
# Out:
# Iraq has the highest attacks with percentage of 24.7%
